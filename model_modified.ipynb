# %% [markdown]
# ### original model

# %%
import torch
import torch.nn as nn
from torchvision.models import resnet50

try:
    from torch.hub import load_state_dict_from_url
except ImportError:
    from torch.utils.model_zoo import load_url as load_state_dict_from_url

model_urls = dict(
    acc_920='https://github.com/khrlimam/facenet/releases/download/acc-0.920/model920-6be7e3e9.pth',
    acc_921='https://github.com/khrlimam/facenet/releases/download/acc-0.92135/model921-af60fb4f.pth'
)

# %%
def load_state(arch, progress=True):
    state = load_state_dict_from_url(model_urls.get(arch), progress=progress)
    return state


def model_920(pretrained=True, progress=True):
    model = FaceNetModel()
    if pretrained:
        state = load_state('acc_920', progress)
        model.load_state_dict(state['state_dict'])
    return model


def model_921(pretrained=True, progress=True):
    model = FaceNetModel()
    if pretrained:
        state = load_state('acc_921', progress)
        model.load_state_dict(state['state_dict'])
    return model


class Flatten(nn.Module):

    def forward(self, x):
        return x.view(x.size(0), -1)

# %%
class FaceNetModel(nn.Module):
    def __init__(self, pretrained=False):
        super(FaceNetModel, self).__init__()

        self.model = resnet50(pretrained)
        embedding_size = 128
        num_classes = 500
        self.cnn = nn.Sequential(
            self.model.conv1,
            self.model.bn1,
            self.model.relu,
            self.model.maxpool,
            self.model.layer1,
            self.model.layer2,
            self.model.layer3,
            self.model.layer4)

        # modify fc layer based on https://arxiv.org/abs/1703.07737
        self.model.fc = nn.Sequential(
            Flatten(),
            # nn.Linear(100352, 1024),
            # nn.BatchNorm1d(1024),
            # nn.ReLU(),
            nn.Linear(100352, embedding_size))

        self.model.classifier = nn.Linear(embedding_size, num_classes)

    def l2_norm(self, input):
        input_size = input.size()
        buffer = torch.pow(input, 2)
        normp = torch.sum(buffer, 1).add_(1e-10)
        norm = torch.sqrt(normp)
        _output = torch.div(input, norm.view(-1, 1).expand_as(input))
        output = _output.view(input_size)
        return output

    def freeze_all(self):
        for param in self.model.parameters():
            param.requires_grad = False

    def unfreeze_all(self):
        for param in self.model.parameters():
            param.requires_grad = True

    def freeze_fc(self):
        for param in self.model.fc.parameters():
            param.requires_grad = False

    def unfreeze_fc(self):
        for param in self.model.fc.parameters():
            param.requires_grad = True

    def freeze_only(self, freeze):
        for name, child in self.model.named_children():
            if name in freeze:
                for param in child.parameters():
                    param.requires_grad = False
            else:
                for param in child.parameters():
                    param.requires_grad = True

    def unfreeze_only(self, unfreeze):
        for name, child in self.model.named_children():
            if name in unfreeze:
                for param in child.parameters():
                    param.requires_grad = True
            else:
                for param in child.parameters():
                    param.requires_grad = False

    # returns face embedding(embedding_size)
    def forward(self, x):
        x = self.cnn(x)
        x = self.model.fc(x)

        features = self.l2_norm(x)
        # Multiply by alpha = 10 as suggested in https://arxiv.org/pdf/1703.09507.pdf
        alpha = 10
        features = features * alpha
        return features

    def forward_classifier(self, x):
        features = self.forward(x)
        res = self.model.classifier(features)
        return res

# %%
model = FaceNetModel(pretrained=False)

# Print number of parameters
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")

# Optional: Detailed layer-wise parameter count
print("\nLayer-wise parameters:")
for name, param in model.named_parameters():
    print(f"{name:50} | Shape: {str(param.shape):20} | Params: {param.numel():,}")

# Dummy input and forward pass
dummy_input = torch.randn(4, 3, 224, 224)
output = model(dummy_input)
print("\nOutput shape:", output.shape)
# Out:
# /Users/kundanyadav/Desktop/iit delhi/iit_D/lib/python3.9/site-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# /Users/kundanyadav/Desktop/iit delhi/iit_D/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Total parameters: 36,417,716
# Trainable parameters: 36,417,716
#
# Layer-wise parameters:
# model.conv1.weight                                 | Shape: torch.Size([64, 3, 7, 7]) | Params: 9,408
# model.bn1.weight                                   | Shape: torch.Size([64])     | Params: 64
# model.bn1.bias                                     | Shape: torch.Size([64])     | Params: 64
# model.layer1.0.conv1.weight                        | Shape: torch.Size([64, 64, 1, 1]) | Params: 4,096
# model.layer1.0.bn1.weight                          | Shape: torch.Size([64])     | Params: 64
# model.layer1.0.bn1.bias                            | Shape: torch.Size([64])     | Params: 64
# model.layer1.0.conv2.weight                        | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer1.0.bn2.weight                          | Shape: torch.Size([64])     | Params: 64
# model.layer1.0.bn2.bias                            | Shape: torch.Size([64])     | Params: 64
# model.layer1.0.conv3.weight                        | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer1.0.bn3.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer1.0.bn3.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer1.0.downsample.0.weight                 | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer1.0.downsample.1.weight                 | Shape: torch.Size([256])    | Params: 256
# model.layer1.0.downsample.1.bias                   | Shape: torch.Size([256])    | Params: 256
# model.layer1.1.conv1.weight                        | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer1.1.bn1.weight                          | Shape: torch.Size([64])     | Params: 64
# model.layer1.1.bn1.bias                            | Shape: torch.Size([64])     | Params: 64
# model.layer1.1.conv2.weight                        | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer1.1.bn2.weight                          | Shape: torch.Size([64])     | Params: 64
# model.layer1.1.bn2.bias                            | Shape: torch.Size([64])     | Params: 64
# model.layer1.1.conv3.weight                        | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer1.1.bn3.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer1.1.bn3.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer1.2.conv1.weight                        | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer1.2.bn1.weight                          | Shape: torch.Size([64])     | Params: 64
# model.layer1.2.bn1.bias                            | Shape: torch.Size([64])     | Params: 64
# model.layer1.2.conv2.weight                        | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer1.2.bn2.weight                          | Shape: torch.Size([64])     | Params: 64
# model.layer1.2.bn2.bias                            | Shape: torch.Size([64])     | Params: 64
# model.layer1.2.conv3.weight                        | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer1.2.bn3.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer1.2.bn3.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer2.0.conv1.weight                        | Shape: torch.Size([128, 256, 1, 1]) | Params: 32,768
# model.layer2.0.bn1.weight                          | Shape: torch.Size([128])    | Params: 128
# model.layer2.0.bn1.bias                            | Shape: torch.Size([128])    | Params: 128
# model.layer2.0.conv2.weight                        | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer2.0.bn2.weight                          | Shape: torch.Size([128])    | Params: 128
# model.layer2.0.bn2.bias                            | Shape: torch.Size([128])    | Params: 128
# model.layer2.0.conv3.weight                        | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer2.0.bn3.weight                          | Shape: torch.Size([512])    | Params: 512
# model.layer2.0.bn3.bias                            | Shape: torch.Size([512])    | Params: 512
# model.layer2.0.downsample.0.weight                 | Shape: torch.Size([512, 256, 1, 1]) | Params: 131,072
# model.layer2.0.downsample.1.weight                 | Shape: torch.Size([512])    | Params: 512
# model.layer2.0.downsample.1.bias                   | Shape: torch.Size([512])    | Params: 512
# model.layer2.1.conv1.weight                        | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer2.1.bn1.weight                          | Shape: torch.Size([128])    | Params: 128
# model.layer2.1.bn1.bias                            | Shape: torch.Size([128])    | Params: 128
# model.layer2.1.conv2.weight                        | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer2.1.bn2.weight                          | Shape: torch.Size([128])    | Params: 128
# model.layer2.1.bn2.bias                            | Shape: torch.Size([128])    | Params: 128
# model.layer2.1.conv3.weight                        | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer2.1.bn3.weight                          | Shape: torch.Size([512])    | Params: 512
# model.layer2.1.bn3.bias                            | Shape: torch.Size([512])    | Params: 512
# model.layer2.2.conv1.weight                        | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer2.2.bn1.weight                          | Shape: torch.Size([128])    | Params: 128
# model.layer2.2.bn1.bias                            | Shape: torch.Size([128])    | Params: 128
# model.layer2.2.conv2.weight                        | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer2.2.bn2.weight                          | Shape: torch.Size([128])    | Params: 128
# model.layer2.2.bn2.bias                            | Shape: torch.Size([128])    | Params: 128
# model.layer2.2.conv3.weight                        | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer2.2.bn3.weight                          | Shape: torch.Size([512])    | Params: 512
# model.layer2.2.bn3.bias                            | Shape: torch.Size([512])    | Params: 512
# model.layer2.3.conv1.weight                        | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer2.3.bn1.weight                          | Shape: torch.Size([128])    | Params: 128
# model.layer2.3.bn1.bias                            | Shape: torch.Size([128])    | Params: 128
# model.layer2.3.conv2.weight                        | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer2.3.bn2.weight                          | Shape: torch.Size([128])    | Params: 128
# model.layer2.3.bn2.bias                            | Shape: torch.Size([128])    | Params: 128
# model.layer2.3.conv3.weight                        | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer2.3.bn3.weight                          | Shape: torch.Size([512])    | Params: 512
# model.layer2.3.bn3.bias                            | Shape: torch.Size([512])    | Params: 512
# model.layer3.0.conv1.weight                        | Shape: torch.Size([256, 512, 1, 1]) | Params: 131,072
# model.layer3.0.bn1.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.0.bn1.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.0.conv2.weight                        | Shape: torch.Size([256, 256, 3, 3]) | Params: 589,824
# model.layer3.0.bn2.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.0.bn2.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.0.conv3.weight                        | Shape: torch.Size([1024, 256, 1, 1]) | Params: 262,144
# model.layer3.0.bn3.weight                          | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.0.bn3.bias                            | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.0.downsample.0.weight                 | Shape: torch.Size([1024, 512, 1, 1]) | Params: 524,288
# model.layer3.0.downsample.1.weight                 | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.0.downsample.1.bias                   | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.1.conv1.weight                        | Shape: torch.Size([256, 1024, 1, 1]) | Params: 262,144
# model.layer3.1.bn1.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.1.bn1.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.1.conv2.weight                        | Shape: torch.Size([256, 256, 3, 3]) | Params: 589,824
# model.layer3.1.bn2.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.1.bn2.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.1.conv3.weight                        | Shape: torch.Size([1024, 256, 1, 1]) | Params: 262,144
# model.layer3.1.bn3.weight                          | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.1.bn3.bias                            | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.2.conv1.weight                        | Shape: torch.Size([256, 1024, 1, 1]) | Params: 262,144
# model.layer3.2.bn1.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.2.bn1.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.2.conv2.weight                        | Shape: torch.Size([256, 256, 3, 3]) | Params: 589,824
# model.layer3.2.bn2.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.2.bn2.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.2.conv3.weight                        | Shape: torch.Size([1024, 256, 1, 1]) | Params: 262,144
# model.layer3.2.bn3.weight                          | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.2.bn3.bias                            | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.3.conv1.weight                        | Shape: torch.Size([256, 1024, 1, 1]) | Params: 262,144
# model.layer3.3.bn1.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.3.bn1.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.3.conv2.weight                        | Shape: torch.Size([256, 256, 3, 3]) | Params: 589,824
# model.layer3.3.bn2.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.3.bn2.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.3.conv3.weight                        | Shape: torch.Size([1024, 256, 1, 1]) | Params: 262,144
# model.layer3.3.bn3.weight                          | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.3.bn3.bias                            | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.4.conv1.weight                        | Shape: torch.Size([256, 1024, 1, 1]) | Params: 262,144
# model.layer3.4.bn1.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.4.bn1.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.4.conv2.weight                        | Shape: torch.Size([256, 256, 3, 3]) | Params: 589,824
# model.layer3.4.bn2.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.4.bn2.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.4.conv3.weight                        | Shape: torch.Size([1024, 256, 1, 1]) | Params: 262,144
# model.layer3.4.bn3.weight                          | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.4.bn3.bias                            | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.5.conv1.weight                        | Shape: torch.Size([256, 1024, 1, 1]) | Params: 262,144
# model.layer3.5.bn1.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.5.bn1.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.5.conv2.weight                        | Shape: torch.Size([256, 256, 3, 3]) | Params: 589,824
# model.layer3.5.bn2.weight                          | Shape: torch.Size([256])    | Params: 256
# model.layer3.5.bn2.bias                            | Shape: torch.Size([256])    | Params: 256
# model.layer3.5.conv3.weight                        | Shape: torch.Size([1024, 256, 1, 1]) | Params: 262,144
# model.layer3.5.bn3.weight                          | Shape: torch.Size([1024])   | Params: 1,024
# model.layer3.5.bn3.bias                            | Shape: torch.Size([1024])   | Params: 1,024
# model.layer4.0.conv1.weight                        | Shape: torch.Size([512, 1024, 1, 1]) | Params: 524,288
# model.layer4.0.bn1.weight                          | Shape: torch.Size([512])    | Params: 512
# model.layer4.0.bn1.bias                            | Shape: torch.Size([512])    | Params: 512
# model.layer4.0.conv2.weight                        | Shape: torch.Size([512, 512, 3, 3]) | Params: 2,359,296
# model.layer4.0.bn2.weight                          | Shape: torch.Size([512])    | Params: 512
# model.layer4.0.bn2.bias                            | Shape: torch.Size([512])    | Params: 512
# model.layer4.0.conv3.weight                        | Shape: torch.Size([2048, 512, 1, 1]) | Params: 1,048,576
# model.layer4.0.bn3.weight                          | Shape: torch.Size([2048])   | Params: 2,048
# model.layer4.0.bn3.bias                            | Shape: torch.Size([2048])   | Params: 2,048
# model.layer4.0.downsample.0.weight                 | Shape: torch.Size([2048, 1024, 1, 1]) | Params: 2,097,152
# model.layer4.0.downsample.1.weight                 | Shape: torch.Size([2048])   | Params: 2,048
# model.layer4.0.downsample.1.bias                   | Shape: torch.Size([2048])   | Params: 2,048
# model.layer4.1.conv1.weight                        | Shape: torch.Size([512, 2048, 1, 1]) | Params: 1,048,576
# model.layer4.1.bn1.weight                          | Shape: torch.Size([512])    | Params: 512
# model.layer4.1.bn1.bias                            | Shape: torch.Size([512])    | Params: 512
# model.layer4.1.conv2.weight                        | Shape: torch.Size([512, 512, 3, 3]) | Params: 2,359,296
# model.layer4.1.bn2.weight                          | Shape: torch.Size([512])    | Params: 512
# model.layer4.1.bn2.bias                            | Shape: torch.Size([512])    | Params: 512
# model.layer4.1.conv3.weight                        | Shape: torch.Size([2048, 512, 1, 1]) | Params: 1,048,576
# model.layer4.1.bn3.weight                          | Shape: torch.Size([2048])   | Params: 2,048
# model.layer4.1.bn3.bias                            | Shape: torch.Size([2048])   | Params: 2,048
# model.layer4.2.conv1.weight                        | Shape: torch.Size([512, 2048, 1, 1]) | Params: 1,048,576
# model.layer4.2.bn1.weight                          | Shape: torch.Size([512])    | Params: 512
# model.layer4.2.bn1.bias                            | Shape: torch.Size([512])    | Params: 512
# model.layer4.2.conv2.weight                        | Shape: torch.Size([512, 512, 3, 3]) | Params: 2,359,296
# model.layer4.2.bn2.weight                          | Shape: torch.Size([512])    | Params: 512
# model.layer4.2.bn2.bias                            | Shape: torch.Size([512])    | Params: 512
# model.layer4.2.conv3.weight                        | Shape: torch.Size([2048, 512, 1, 1]) | Params: 1,048,576
# model.layer4.2.bn3.weight                          | Shape: torch.Size([2048])   | Params: 2,048
# model.layer4.2.bn3.bias                            | Shape: torch.Size([2048])   | Params: 2,048
# model.fc.1.weight                                  | Shape: torch.Size([128, 100352]) | Params: 12,845,056
# model.fc.1.bias                                    | Shape: torch.Size([128])    | Params: 128
# model.classifier.weight                            | Shape: torch.Size([500, 128]) | Params: 64,000
# model.classifier.bias                              | Shape: torch.Size([500])    | Params: 500
#
# Output shape: torch.Size([4, 128])

# %% [markdown]
# ### modified model

# %%
import torch
import torch.nn as nn
from torchvision.models import resnet50
from core_qnn import *
from ReLu import Relu
from core_qnn.quaternion_layers import QuaternionConv
from BatchNormalization import QuaternionBatchNorm2d
from InstanceNormalization import QuaternionInstanceNorm2d
from core_qnn.quaternion_layers import QuaternionLinearAutograd
import numpy



try:
    from torch.hub import load_state_dict_from_url
except ImportError:
    from torch.utils.model_zoo import load_url as load_state_dict_from_url

model_urls = dict(
    acc_920='https://github.com/khrlimam/facenet/releases/download/acc-0.920/model920-6be7e3e9.pth',
    acc_921='https://github.com/khrlimam/facenet/releases/download/acc-0.92135/model921-af60fb4f.pth'
)

# %%
def load_state(arch, progress=True):
    state = load_state_dict_from_url(model_urls.get(arch), progress=progress)
    return state


def model_920(pretrained=True, progress=True):
    model = FaceNetModel()
    if pretrained:
        state = load_state('acc_920', progress)
        model.load_state_dict(state['state_dict'])
    return model


def model_921(pretrained=True, progress=True):
    model = FaceNetModel()
    if pretrained:
        state = load_state('acc_921', progress)
        model.load_state_dict(state['state_dict'])
    return model


class Flatten(nn.Module):

    def forward(self, x):
        return x.view(x.size(0), -1)

# %%
class FaceNetModel(nn.Module):
    def __init__(self, pretrained=False):
        super(FaceNetModel, self).__init__()

        # Initialize base model without pretrained weights (quaternions aren't in ImageNet-pretrained models)
        self.model = resnet50(pretrained=False)

        # Replace first conv with quaternion conv (adjust out_channels for compatibility)
        self.model.conv1 = QuaternionConv(
            in_channels=4,        # 4 channels: e.g., RGB + extra channel
            out_channels=64,      # 64 real channels (i.e. 16 quaternion channels)
            kernel_size=7,
            stride=2,
            padding=3,
            bias=False
        )
        self.model.bn1 = QuaternionBatchNorm2d(64)
        self.model.relu = nn.ReLU()
        self.model.layer1 = self._replace_resnet_layer(self.model.layer1, 64, 64)      # Outputs 64*4 = 256 channels
        self.model.layer2 = self._replace_resnet_layer(self.model.layer2, 256, 128)     # Outputs 128*4 = 512 channels
        self.model.layer3 = self._replace_resnet_layer(self.model.layer3, 512, 256)     # Outputs 256*4 = 1024 channels
        self.model.layer4 = self._replace_resnet_layer(self.model.layer4, 1024, 512)    # Outputs 512*4 = 2048 channels
    

        # Update avgpool and fully connected layers
        self.model.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.model.fc = QuaternionLinearAutograd(2048, 128)
  # 512 real -> 128 quaternion
        
        # Classifier
        self.classifier = QuaternionLinearAutograd(128, 500)
    
    def _replace_resnet_layer(self, layer, in_channels, out_channels):
        expansion = 4  # For ResNet50 Bottleneck blocks
        for i in range(len(layer)):
            block = layer[i]
            # Replace conv1: use a 1x1 convolution to reduce channels
            block.conv1 = QuaternionConv(in_channels, out_channels, kernel_size=1, stride=block.conv1.stride, bias=False)
            block.bn1 = QuaternionBatchNorm2d(out_channels)
            
            # Replace conv2: 3x3 convolution
            block.conv2 = QuaternionConv(out_channels, out_channels, kernel_size=3, stride=block.conv2.stride, padding=1, bias=False)
            block.bn2 = QuaternionBatchNorm2d(out_channels)
            
            # Replace conv3: 1x1 convolution to expand channels
            block.conv3 = QuaternionConv(out_channels, out_channels * expansion, kernel_size=1, stride=1, bias=False)
            block.bn3 = QuaternionBatchNorm2d(out_channels * expansion)
            
            # Replace downsample if it exists so that it outputs out_channels * expansion channels
            if block.downsample:
                block.downsample[0] = QuaternionConv(in_channels, out_channels * expansion, kernel_size=1, stride=block.downsample[0].stride, bias=False)
                block.downsample[1] = QuaternionBatchNorm2d(out_channels * expansion)
            in_channels = out_channels * expansion  # update for subsequent blocks in this layer
        return layer



    def quaternion_l2_norm(self, x):
        """L2 normalization adapted for quaternion tensors."""
        real, i, j, k = torch.chunk(x, 4, dim=1)
        norm = torch.sqrt(real**2 + i**2 + j**2 + k**2 + 1e-10)
        return torch.cat([real/norm, i/norm, j/norm, k/norm], dim=1)

    def forward(self, x):
        
        x = self.model.conv1(x)
        print("shape of x before batch normalization" ,x.shape)
        x = self.model.bn1(x)
        x = self.model.relu(x)
        x = self.model.maxpool(x)
        print("shape of x before layers ", x.shape)
        x = self.model.layer1(x)
        x = self.model.layer2(x)
        x = self.model.layer3(x)
        x = self.model.layer4(x)
        x = self.model.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.model.fc(x)
        return self.quaternion_l2_norm(x)

# %%
model = FaceNetModel(pretrained=False)

# Print number of parameters
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")

# Optional: Detailed layer-wise parameter count
print("\nLayer-wise parameters:")
for name, param in model.named_parameters():
    print(f"{name:50} | Shape: {str(param.shape):20} | Params: {param.numel():,}")

# Dummy input and forward pass
dummy_input = torch.randn(4, 3, 224, 224)
dummy_input = torch.cat([dummy_input, torch.zeros(4, 1, 224, 224)], dim=1)  # Shape: [4, 4, 224, 224]
output = model(dummy_input)
print("\nOutput shape:", output.shape)
# Out:
# Total parameters: 5,979,876
# Trainable parameters: 5,979,876
#
# Layer-wise parameters:
# model.conv1.r_weight                               | Shape: torch.Size([16, 1, 7, 7]) | Params: 784
# model.conv1.i_weight                               | Shape: torch.Size([16, 1, 7, 7]) | Params: 784
# model.conv1.j_weight                               | Shape: torch.Size([16, 1, 7, 7]) | Params: 784
# model.conv1.k_weight                               | Shape: torch.Size([16, 1, 7, 7]) | Params: 784
# model.bn1.gamma                                    | Shape: torch.Size([1, 16, 1, 1]) | Params: 16
# model.bn1.beta                                     | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.0.conv1.r_weight                      | Shape: torch.Size([16, 16, 1, 1]) | Params: 256
# model.layer1.0.conv1.i_weight                      | Shape: torch.Size([16, 16, 1, 1]) | Params: 256
# model.layer1.0.conv1.j_weight                      | Shape: torch.Size([16, 16, 1, 1]) | Params: 256
# model.layer1.0.conv1.k_weight                      | Shape: torch.Size([16, 16, 1, 1]) | Params: 256
# model.layer1.0.bn1.gamma                           | Shape: torch.Size([1, 16, 1, 1]) | Params: 16
# model.layer1.0.bn1.beta                            | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.0.conv2.r_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.0.conv2.i_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.0.conv2.j_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.0.conv2.k_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.0.bn2.gamma                           | Shape: torch.Size([1, 16, 1, 1]) | Params: 16
# model.layer1.0.bn2.beta                            | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.0.conv3.r_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.0.conv3.i_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.0.conv3.j_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.0.conv3.k_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.0.bn3.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.0.bn3.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer1.0.downsample.0.r_weight               | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.0.downsample.0.i_weight               | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.0.downsample.0.j_weight               | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.0.downsample.0.k_weight               | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.0.downsample.1.gamma                  | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.0.downsample.1.beta                   | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer1.1.conv1.r_weight                      | Shape: torch.Size([16, 64, 1, 1]) | Params: 1,024
# model.layer1.1.conv1.i_weight                      | Shape: torch.Size([16, 64, 1, 1]) | Params: 1,024
# model.layer1.1.conv1.j_weight                      | Shape: torch.Size([16, 64, 1, 1]) | Params: 1,024
# model.layer1.1.conv1.k_weight                      | Shape: torch.Size([16, 64, 1, 1]) | Params: 1,024
# model.layer1.1.bn1.gamma                           | Shape: torch.Size([1, 16, 1, 1]) | Params: 16
# model.layer1.1.bn1.beta                            | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.1.conv2.r_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.1.conv2.i_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.1.conv2.j_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.1.conv2.k_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.1.bn2.gamma                           | Shape: torch.Size([1, 16, 1, 1]) | Params: 16
# model.layer1.1.bn2.beta                            | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.1.conv3.r_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.1.conv3.i_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.1.conv3.j_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.1.conv3.k_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.1.bn3.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.1.bn3.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer1.2.conv1.r_weight                      | Shape: torch.Size([16, 64, 1, 1]) | Params: 1,024
# model.layer1.2.conv1.i_weight                      | Shape: torch.Size([16, 64, 1, 1]) | Params: 1,024
# model.layer1.2.conv1.j_weight                      | Shape: torch.Size([16, 64, 1, 1]) | Params: 1,024
# model.layer1.2.conv1.k_weight                      | Shape: torch.Size([16, 64, 1, 1]) | Params: 1,024
# model.layer1.2.bn1.gamma                           | Shape: torch.Size([1, 16, 1, 1]) | Params: 16
# model.layer1.2.bn1.beta                            | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.2.conv2.r_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.2.conv2.i_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.2.conv2.j_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.2.conv2.k_weight                      | Shape: torch.Size([16, 16, 3, 3]) | Params: 2,304
# model.layer1.2.bn2.gamma                           | Shape: torch.Size([1, 16, 1, 1]) | Params: 16
# model.layer1.2.bn2.beta                            | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.2.conv3.r_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.2.conv3.i_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.2.conv3.j_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.2.conv3.k_weight                      | Shape: torch.Size([64, 16, 1, 1]) | Params: 1,024
# model.layer1.2.bn3.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer1.2.bn3.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer2.0.conv1.r_weight                      | Shape: torch.Size([32, 64, 1, 1]) | Params: 2,048
# model.layer2.0.conv1.i_weight                      | Shape: torch.Size([32, 64, 1, 1]) | Params: 2,048
# model.layer2.0.conv1.j_weight                      | Shape: torch.Size([32, 64, 1, 1]) | Params: 2,048
# model.layer2.0.conv1.k_weight                      | Shape: torch.Size([32, 64, 1, 1]) | Params: 2,048
# model.layer2.0.bn1.gamma                           | Shape: torch.Size([1, 32, 1, 1]) | Params: 32
# model.layer2.0.bn1.beta                            | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.0.conv2.r_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.0.conv2.i_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.0.conv2.j_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.0.conv2.k_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.0.bn2.gamma                           | Shape: torch.Size([1, 32, 1, 1]) | Params: 32
# model.layer2.0.bn2.beta                            | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.0.conv3.r_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.0.conv3.i_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.0.conv3.j_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.0.conv3.k_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.0.bn3.gamma                           | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.0.bn3.beta                            | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer2.0.downsample.0.r_weight               | Shape: torch.Size([128, 64, 1, 1]) | Params: 8,192
# model.layer2.0.downsample.0.i_weight               | Shape: torch.Size([128, 64, 1, 1]) | Params: 8,192
# model.layer2.0.downsample.0.j_weight               | Shape: torch.Size([128, 64, 1, 1]) | Params: 8,192
# model.layer2.0.downsample.0.k_weight               | Shape: torch.Size([128, 64, 1, 1]) | Params: 8,192
# model.layer2.0.downsample.1.gamma                  | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.0.downsample.1.beta                   | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer2.1.conv1.r_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.1.conv1.i_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.1.conv1.j_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.1.conv1.k_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.1.bn1.gamma                           | Shape: torch.Size([1, 32, 1, 1]) | Params: 32
# model.layer2.1.bn1.beta                            | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.1.conv2.r_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.1.conv2.i_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.1.conv2.j_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.1.conv2.k_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.1.bn2.gamma                           | Shape: torch.Size([1, 32, 1, 1]) | Params: 32
# model.layer2.1.bn2.beta                            | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.1.conv3.r_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.1.conv3.i_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.1.conv3.j_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.1.conv3.k_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.1.bn3.gamma                           | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.1.bn3.beta                            | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer2.2.conv1.r_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.2.conv1.i_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.2.conv1.j_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.2.conv1.k_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.2.bn1.gamma                           | Shape: torch.Size([1, 32, 1, 1]) | Params: 32
# model.layer2.2.bn1.beta                            | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.2.conv2.r_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.2.conv2.i_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.2.conv2.j_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.2.conv2.k_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.2.bn2.gamma                           | Shape: torch.Size([1, 32, 1, 1]) | Params: 32
# model.layer2.2.bn2.beta                            | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.2.conv3.r_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.2.conv3.i_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.2.conv3.j_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.2.conv3.k_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.2.bn3.gamma                           | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.2.bn3.beta                            | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer2.3.conv1.r_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.3.conv1.i_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.3.conv1.j_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.3.conv1.k_weight                      | Shape: torch.Size([32, 128, 1, 1]) | Params: 4,096
# model.layer2.3.bn1.gamma                           | Shape: torch.Size([1, 32, 1, 1]) | Params: 32
# model.layer2.3.bn1.beta                            | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.3.conv2.r_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.3.conv2.i_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.3.conv2.j_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.3.conv2.k_weight                      | Shape: torch.Size([32, 32, 3, 3]) | Params: 9,216
# model.layer2.3.bn2.gamma                           | Shape: torch.Size([1, 32, 1, 1]) | Params: 32
# model.layer2.3.bn2.beta                            | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.3.conv3.r_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.3.conv3.i_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.3.conv3.j_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.3.conv3.k_weight                      | Shape: torch.Size([128, 32, 1, 1]) | Params: 4,096
# model.layer2.3.bn3.gamma                           | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer2.3.bn3.beta                            | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer3.0.conv1.r_weight                      | Shape: torch.Size([64, 128, 1, 1]) | Params: 8,192
# model.layer3.0.conv1.i_weight                      | Shape: torch.Size([64, 128, 1, 1]) | Params: 8,192
# model.layer3.0.conv1.j_weight                      | Shape: torch.Size([64, 128, 1, 1]) | Params: 8,192
# model.layer3.0.conv1.k_weight                      | Shape: torch.Size([64, 128, 1, 1]) | Params: 8,192
# model.layer3.0.bn1.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.0.bn1.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.0.conv2.r_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.0.conv2.i_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.0.conv2.j_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.0.conv2.k_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.0.bn2.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.0.bn2.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.0.conv3.r_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.0.conv3.i_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.0.conv3.j_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.0.conv3.k_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.0.bn3.gamma                           | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.0.bn3.beta                            | Shape: torch.Size([1, 1024, 1, 1]) | Params: 1,024
# model.layer3.0.downsample.0.r_weight               | Shape: torch.Size([256, 128, 1, 1]) | Params: 32,768
# model.layer3.0.downsample.0.i_weight               | Shape: torch.Size([256, 128, 1, 1]) | Params: 32,768
# model.layer3.0.downsample.0.j_weight               | Shape: torch.Size([256, 128, 1, 1]) | Params: 32,768
# model.layer3.0.downsample.0.k_weight               | Shape: torch.Size([256, 128, 1, 1]) | Params: 32,768
# model.layer3.0.downsample.1.gamma                  | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.0.downsample.1.beta                   | Shape: torch.Size([1, 1024, 1, 1]) | Params: 1,024
# model.layer3.1.conv1.r_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.1.conv1.i_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.1.conv1.j_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.1.conv1.k_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.1.bn1.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.1.bn1.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.1.conv2.r_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.1.conv2.i_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.1.conv2.j_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.1.conv2.k_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.1.bn2.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.1.bn2.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.1.conv3.r_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.1.conv3.i_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.1.conv3.j_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.1.conv3.k_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.1.bn3.gamma                           | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.1.bn3.beta                            | Shape: torch.Size([1, 1024, 1, 1]) | Params: 1,024
# model.layer3.2.conv1.r_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.2.conv1.i_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.2.conv1.j_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.2.conv1.k_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.2.bn1.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.2.bn1.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.2.conv2.r_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.2.conv2.i_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.2.conv2.j_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.2.conv2.k_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.2.bn2.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.2.bn2.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.2.conv3.r_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.2.conv3.i_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.2.conv3.j_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.2.conv3.k_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.2.bn3.gamma                           | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.2.bn3.beta                            | Shape: torch.Size([1, 1024, 1, 1]) | Params: 1,024
# model.layer3.3.conv1.r_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.3.conv1.i_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.3.conv1.j_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.3.conv1.k_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.3.bn1.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.3.bn1.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.3.conv2.r_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.3.conv2.i_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.3.conv2.j_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.3.conv2.k_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.3.bn2.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.3.bn2.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.3.conv3.r_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.3.conv3.i_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.3.conv3.j_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.3.conv3.k_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.3.bn3.gamma                           | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.3.bn3.beta                            | Shape: torch.Size([1, 1024, 1, 1]) | Params: 1,024
# model.layer3.4.conv1.r_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.4.conv1.i_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.4.conv1.j_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.4.conv1.k_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.4.bn1.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.4.bn1.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.4.conv2.r_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.4.conv2.i_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.4.conv2.j_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.4.conv2.k_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.4.bn2.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.4.bn2.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.4.conv3.r_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.4.conv3.i_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.4.conv3.j_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.4.conv3.k_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.4.bn3.gamma                           | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.4.bn3.beta                            | Shape: torch.Size([1, 1024, 1, 1]) | Params: 1,024
# model.layer3.5.conv1.r_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.5.conv1.i_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.5.conv1.j_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.5.conv1.k_weight                      | Shape: torch.Size([64, 256, 1, 1]) | Params: 16,384
# model.layer3.5.bn1.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.5.bn1.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.5.conv2.r_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.5.conv2.i_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.5.conv2.j_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.5.conv2.k_weight                      | Shape: torch.Size([64, 64, 3, 3]) | Params: 36,864
# model.layer3.5.bn2.gamma                           | Shape: torch.Size([1, 64, 1, 1]) | Params: 64
# model.layer3.5.bn2.beta                            | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.5.conv3.r_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.5.conv3.i_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.5.conv3.j_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.5.conv3.k_weight                      | Shape: torch.Size([256, 64, 1, 1]) | Params: 16,384
# model.layer3.5.bn3.gamma                           | Shape: torch.Size([1, 256, 1, 1]) | Params: 256
# model.layer3.5.bn3.beta                            | Shape: torch.Size([1, 1024, 1, 1]) | Params: 1,024
# model.layer4.0.conv1.r_weight                      | Shape: torch.Size([128, 256, 1, 1]) | Params: 32,768
# model.layer4.0.conv1.i_weight                      | Shape: torch.Size([128, 256, 1, 1]) | Params: 32,768
# model.layer4.0.conv1.j_weight                      | Shape: torch.Size([128, 256, 1, 1]) | Params: 32,768
# model.layer4.0.conv1.k_weight                      | Shape: torch.Size([128, 256, 1, 1]) | Params: 32,768
# model.layer4.0.bn1.gamma                           | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer4.0.bn1.beta                            | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer4.0.conv2.r_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.0.conv2.i_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.0.conv2.j_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.0.conv2.k_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.0.bn2.gamma                           | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer4.0.bn2.beta                            | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer4.0.conv3.r_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.0.conv3.i_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.0.conv3.j_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.0.conv3.k_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.0.bn3.gamma                           | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer4.0.bn3.beta                            | Shape: torch.Size([1, 2048, 1, 1]) | Params: 2,048
# model.layer4.0.downsample.0.r_weight               | Shape: torch.Size([512, 256, 1, 1]) | Params: 131,072
# model.layer4.0.downsample.0.i_weight               | Shape: torch.Size([512, 256, 1, 1]) | Params: 131,072
# model.layer4.0.downsample.0.j_weight               | Shape: torch.Size([512, 256, 1, 1]) | Params: 131,072
# model.layer4.0.downsample.0.k_weight               | Shape: torch.Size([512, 256, 1, 1]) | Params: 131,072
# model.layer4.0.downsample.1.gamma                  | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer4.0.downsample.1.beta                   | Shape: torch.Size([1, 2048, 1, 1]) | Params: 2,048
# model.layer4.1.conv1.r_weight                      | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer4.1.conv1.i_weight                      | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer4.1.conv1.j_weight                      | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer4.1.conv1.k_weight                      | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer4.1.bn1.gamma                           | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer4.1.bn1.beta                            | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer4.1.conv2.r_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.1.conv2.i_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.1.conv2.j_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.1.conv2.k_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.1.bn2.gamma                           | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer4.1.bn2.beta                            | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer4.1.conv3.r_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.1.conv3.i_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.1.conv3.j_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.1.conv3.k_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.1.bn3.gamma                           | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer4.1.bn3.beta                            | Shape: torch.Size([1, 2048, 1, 1]) | Params: 2,048
# model.layer4.2.conv1.r_weight                      | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer4.2.conv1.i_weight                      | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer4.2.conv1.j_weight                      | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer4.2.conv1.k_weight                      | Shape: torch.Size([128, 512, 1, 1]) | Params: 65,536
# model.layer4.2.bn1.gamma                           | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer4.2.bn1.beta                            | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer4.2.conv2.r_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.2.conv2.i_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.2.conv2.j_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.2.conv2.k_weight                      | Shape: torch.Size([128, 128, 3, 3]) | Params: 147,456
# model.layer4.2.bn2.gamma                           | Shape: torch.Size([1, 128, 1, 1]) | Params: 128
# model.layer4.2.bn2.beta                            | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer4.2.conv3.r_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.2.conv3.i_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.2.conv3.j_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.2.conv3.k_weight                      | Shape: torch.Size([512, 128, 1, 1]) | Params: 65,536
# model.layer4.2.bn3.gamma                           | Shape: torch.Size([1, 512, 1, 1]) | Params: 512
# model.layer4.2.bn3.beta                            | Shape: torch.Size([1, 2048, 1, 1]) | Params: 2,048
# model.fc.r_weight                                  | Shape: torch.Size([512, 32]) | Params: 16,384
# model.fc.i_weight                                  | Shape: torch.Size([512, 32]) | Params: 16,384
# model.fc.j_weight                                  | Shape: torch.Size([512, 32]) | Params: 16,384
# model.fc.k_weight                                  | Shape: torch.Size([512, 32]) | Params: 16,384
# model.fc.bias                                      | Shape: torch.Size([128])    | Params: 128
# classifier.r_weight                                | Shape: torch.Size([32, 125]) | Params: 4,000
# classifier.i_weight                                | Shape: torch.Size([32, 125]) | Params: 4,000
# classifier.j_weight                                | Shape: torch.Size([32, 125]) | Params: 4,000
# classifier.k_weight                                | Shape: torch.Size([32, 125]) | Params: 4,000
# classifier.bias                                    | Shape: torch.Size([500])    | Params: 500
# shape of x before batch normalization torch.Size([4, 64, 112, 112])
# shape of x before layers  torch.Size([4, 64, 56, 56])
#
# Output shape: torch.Size([4, 128])

# %%
import numpy as np
print(np.__version__)
